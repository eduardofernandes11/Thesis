# %% [markdown]
# # Metadata Analysis
#
# Notebook created to perform the pre-processing, feature extraction, training and testing of metadata from .eml files on some Deep Learning models.

# %%
# install dependencies
# !pip install gensim
# !pip install nltk

# %%
# imports
import email
import os
from email.policy import default
import re
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
import nltk

# %% [markdown]
# ### Import phishing and ham data

# %%
# headers to be extracted
selected_headers = ['Subject', 'Date', 'From', 'To', 'Return-Path', 'Reply-To', 'Message-ID', 'Received-SPF', 'Authentication-Results', 'Content-Type', 'MIME-Version']

# %%
# function to extract the headers from the ham .eml files
def extract_eml_headers(source_folders):    
    
    # List to hold all headers from all emails
    headers_list = []
    counter = 0

    for website_folder in source_folders:
        # List all .eml files in the current source folder
        for email_folder in os.listdir(website_folder):
            if os.path.isdir(os.path.join(website_folder, email_folder)):
                for filename in os.listdir(os.path.join(website_folder, email_folder)):
                    if filename.endswith('.eml') and counter < 500:
                        source_path = os.path.join(website_folder, email_folder, filename)
                        
                        # Open and read the .eml file
                        with open(source_path, 'r', encoding='utf-8') as file:
                            eml_content = file.read()

                        # Parse the .eml content to get the message object
                        msg = email.message_from_string(eml_content, policy=default)

                        # Extract only selected headers/metadata into a dictionary
                        headers_dict = {header: msg[header] for header in selected_headers if header in msg}
                        
                        # Add the dictionary to the list for later processing
                        headers_list.append(headers_dict)

                        counter += 1

                        # Your preprocessing steps could go here, on headers_list or headers_dict before saving
                        # Example preprocessing could be:
                        # - Filtering specific headers
                        # - Cleaning header values
                        # - Etc.
    
    return headers_list

# get headers from the ham emails
source_path = '../../privacymail-dataset/data/'
source_folders = [source_path + folder for folder in os.listdir(source_path) if os.path.isdir(os.path.join(source_path, folder))]
ham_headers_list = extract_eml_headers(source_folders)

# %%
# get the already extracted headers from the phishing emails
def get_eml_headers(source_folder):
    # List to hold all headers from all emails
    headers_list = []

    for filename in os.listdir(source_folder):
        if filename.endswith('.eml'):
            source_path = os.path.join(source_folder, filename)

            # Open and read the .eml file
            with open(source_path, 'r', encoding='utf-8') as file:
                eml_content = file.read()

            # Parse the .eml content to get the message object
            msg = email.message_from_string(eml_content, policy=default)

            # Extract only selected headers/metadata into a dictionary
            headers_dict = {header: msg[header] for header in selected_headers if header in msg}

            # Add the dictionary to the list for later processing
            headers_list.append(headers_dict)

    return headers_list


# get headers from the phishing emails
source_folder = '../../EmailsHeaders'
phishing_headers_list = get_eml_headers(source_folder)

# %%
print(ham_headers_list[0])
print(phishing_headers_list[0])
print(len(ham_headers_list))
print(len(phishing_headers_list))

with open('phishing_subjects.txt', 'w') as f:
    for item in phishing_headers_list:
        f.write("%s\n" % item.get('Subject'))
# Out:
# {'Subject': 'Bitte bestätigen Sie Ihr Newsletter-Abonnement', 'Date': 'Thu, 27 Aug 2020 18:54:29 +0200', 'From': 'Sparkasse zu Lübeck AG <newsletter@sparkasse-luebeck.de>', 'To': 'christopher.casto@privacy-mail.org', 'Return-Path': '<hbbj.d.afbi=bounce@bounces.sendnode.com>', 'Reply-To': 'newsletter@sparkasse-luebeck.de', 'Message-ID': '<6cc.4.199@sendnode.com>', 'Received-SPF': 'pass (mx2e90: domain of bounces.sendnode.com designates 185.98.184.207 as permitted sender) client-ip=185.98.184.207; envelope-from=hbbj.d.afbi=bounce@bounces.sendnode.com; helo=mda3cf.sendnode.com;', 'Authentication-Results': 'mx2e90;\tdkim=pass header.d=sendnode.com;        spf=pass (sender IP is 185.98.184.207) smtp.mailfrom=hbbj.d.afbi=bounce@bounces.sendnode.com smtp.helo=mda3cf.sendnode.com', 'Content-Type': 'text/plain; charset="UTF-8"', 'MIME-Version': '1.0'}
# {'Subject': 'Verify your email address to avoid deactivation', 'Date': 'Tue, 23 Jan 2024 08:32:08 +0200', 'From': 'Det IT Support <n-reply@safesopkoco.com>', 'To': 'vieira@det.ua.pt', 'Return-Path': 'n-reply@safesopkoco.com', 'Message-ID': '<20240123083208.13F75BEDDE511554@safesopkoco.com>', 'Received-SPF': 'PermError (mx4.ua.pt: cannot correctly interpret  sender authenticity information from domain of  n-reply@safesopkoco.com) identity=mailfrom;  client-ip=176.117.76.112; receiver=mx4.ua.pt;  envelope-from="n-reply@safesopkoco.com";  x-sender="n-reply@safesopkoco.com"; x-conformance=spf_only', 'Authentication-Results': 'mx4.ua.pt; spf=PermError smtp.mailfrom=n-reply@safesopkoco.com; spf=None smtp.helo=postmaster@mail.safesopkoco.com; dkim=pass (signature verified) header.i=@safesopkoco.com; dmarc=pass (p=none dis=none) d=safesopkoco.com', 'Content-Type': 'multipart/alternative; boundary="B_3788843362_2715154253"', 'MIME-Version': '1.0'}
# 500
# 55

# %%
def extract_email(header_value):
    """Extracts email address from a header value."""
    match = re.search(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b', header_value)
    if match:
        return match.group(0).lower()  # Convert to lower case for case-insensitive comparison
    return ""

def preprocess_email_headers_for_phishing_detection(headers_list):

    # Placeholder for the dataset
    dataset = []

    for headers in headers_list:
        print(headers)
        # Start with an empty data point
        data_point = {
            'from_return_path_mismatch': 0,
            'reply_to_from_mismatch': 0,
            # 'subject_suspicious': 0,
            # 'date_inconsistent': 0,
            # 'to_unspecific': 0
            # Additional features can be added here
        }

        # Normalize and compare "From" and "Return-Path"
        from_email = extract_email(headers.get('From', ''))
        return_path_email = extract_email(headers.get('Return-Path', ''))
        print("from ", from_email)
        print("return ", return_path_email)
        if from_email != return_path_email:
            data_point['from_return_path_mismatch'] = 1

        # Normalize and compare "Reply-To" and "From"
        reply_to_email = extract_email(headers.get('Reply-To', ''))
        print("reply ", reply_to_email)
        if reply_to_email and from_email and reply_to_email != from_email:
            data_point['reply_to_from_mismatch'] = 1

        
        # Simplified check for suspicious "Subject" (can be enhanced)
        # if 'urgent' in headers.get('Subject', '').lower() or 'important' in headers.get('Subject', '').lower():
        #     data_point['subject_suspicious'] = 1
        
        # Example check for "Date" inconsistency (simplified)
        # This should be expanded based on your logic for date checking
        
        # Example check for unspecific "To" (simplified)
        # if headers.get('To') and ('undisclosed recipients' in headers.get('To').lower() or 'all' in headers.get('To').lower()):
        #     data_point['to_unspecific'] = 1

        dataset.append(data_point)

    # Save or return the dataset for DL model
    # For demonstration, let's just return it
    return dataset

# Example usage
ham_dataset = preprocess_email_headers_for_phishing_detection(phishing_headers_list)

print(ham_dataset)

# You can then save this dataset to a file or use it directly for training/testing your DL model
# Out:
# {'Subject': 'Verify your email address to avoid deactivation', 'Date': 'Tue, 23 Jan 2024 08:32:08 +0200', 'From': 'Det IT Support <n-reply@safesopkoco.com>', 'To': 'vieira@det.ua.pt', 'Return-Path': 'n-reply@safesopkoco.com', 'Message-ID': '<20240123083208.13F75BEDDE511554@safesopkoco.com>', 'Received-SPF': 'PermError (mx4.ua.pt: cannot correctly interpret  sender authenticity information from domain of  n-reply@safesopkoco.com) identity=mailfrom;  client-ip=176.117.76.112; receiver=mx4.ua.pt;  envelope-from="n-reply@safesopkoco.com";  x-sender="n-reply@safesopkoco.com"; x-conformance=spf_only', 'Authentication-Results': 'mx4.ua.pt; spf=PermError smtp.mailfrom=n-reply@safesopkoco.com; spf=None smtp.helo=postmaster@mail.safesopkoco.com; dkim=pass (signature verified) header.i=@safesopkoco.com; dmarc=pass (p=none dis=none) d=safesopkoco.com', 'Content-Type': 'multipart/alternative; boundary="B_3788843362_2715154253"', 'MIME-Version': '1.0'}
# from  n-reply@safesopkoco.com
# return  n-reply@safesopkoco.com
# reply
# {'Subject': 'Aberrtura o procedimento co', 'Date': 'Tue, 27 Feb 2024 09:25:45 +0000', 'From': 'STIC-Geral <BBogisich@nafaa.id>', 'To': 'Secretaria dos sTIC <stic-secretaria@ua.pt>', 'Message-ID': '<05312f74-4fb3-4c9f-b4cb-ddc959be3fcc@nafaa.id>', 'Received-SPF': 'None (mx4.ua.pt: no sender authenticity information  available from domain of  postmaster@seagreen.cherry.relay.mailchannels.net)  identity=helo; client-ip=23.83.223.160; receiver=mx4.ua.pt;  envelope-from="BBogisich@nafaa.id";  x-sender="postmaster@seagreen.cherry.relay.mailchannels.net";  x-conformance=spf_only', 'Content-Type': 'multipart/mixed; boundary="_004_05312f744fb34c9fb4cbddc959be3fccnafaaid_"', 'MIME-Version': '1.0'}
# from  bbogisich@nafaa.id
# return
# reply
# {'Subject': '100% BONUS up to €150 or $200 + 100 Free Spins', 'Date': 'Mon, 26 Feb 2024 21:38:07 +0000', 'From': 'BET AMO <yadayada84@yoursurprise.live>', 'To': 'yadayada84@hotmail.com', 'Return-Path': '5s1W6HUFATzK@yoursurprise.live', 'Reply-To': 'yadayada84_5s1W6HUFATzK@yoursurprise.live', 'Message-ID': '<e0217773-1a58-484c-9f87-55c52a23f09f@CO1PEPF000044FC.namprd21.prod.outlook.com>', 'Received-SPF': 'SoftFail (protection.outlook.com: domain of transitioning yoursurprise.live discourages use of 109.228.47.93 as permitted sender)', 'Authentication-Results': 'spf=softfail (sender IP is 109.228.47.93) smtp.mailfrom=yoursurprise.live; dkim=none (message not signed) header.d=none;dmarc=none action=none header.from=yoursurprise.live;compauth=fail reason=001', 'Content-Type': 'text/html;', 'MIME-Version': '1.0'}
# from  yadayada84@yoursurprise.live
# return  5s1w6hufatzk@yoursurprise.live
# reply  yadayada84_5s1w6hufatzk@yoursurprise.live
# {'Subject': 'RGPD – Maior Privacidade, Maior Segurança', 'Date': 'Tue, 17 Oct 2023 09:41:04 +0100', 'From': 'ZuGruppe - Master Nacional <rgpd@egorealestate.com>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'rgpd@egorealestate.com', 'Reply-To': 'ZuGruppe - Master Nacional <info@zugruppe.com>', 'Message-ID': '<ca7d6ae5-54bf-45c9-9269-fc3caa044d99@BN1NAM02FT022.eop-nam02.prod.protection.outlook.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of egorealestate.com designates 213.13.156.168 as permitted sender) receiver=protection.outlook.com; client-ip=213.13.156.168; helo=mx1.newsletter.egorealestate.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 213.13.156.168) smtp.mailfrom=egorealestate.com; dkim=pass (signature was verified) header.d=egorealestate.com;dmarc=pass action=none header.from=egorealestate.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="--boundary_2790_1e9d5497-5532-4d61-8666-420f6815b87d"', 'MIME-Version': '1.0'}
# from  rgpd@egorealestate.com
# return  rgpd@egorealestate.com
# reply  info@zugruppe.com
# {'Subject': 'RESOLVA ISSO O MAIS RÁPIDO POSSÍVEL(Grave-Acusação).', 'Date': 'Fri, 24 Nov 2023 17:26:11 +0000', 'From': 'ÚLTIMO AVISO <0000zzzz099@gmail.com>', 'To': '"in.ter-pol@portugal.pt" <in.ter-pol@portugal.pt>, "pol-in.te@inter-national.com" <pol-in.te@inter-national.com>', 'Message-ID': ' \t<CABGx6RKX=5xDbFNVKpis7vcjLWGCgXdfHbiRDH_vZWKGDY=V5A@mail.gmail.com>', 'Received-SPF': 'None (mx1.ua.pt: no sender authenticity information  available from domain of postmaster@mail-oi1-f178.google.com)  identity=helo; client-ip=209.85.167.178; receiver=mx1.ua.pt;  envelope-from="bassenoutoure@gmail.com";  x-sender="postmaster@mail-oi1-f178.google.com";  x-conformance=spf_only', 'Content-Type': 'multipart/related; boundary="_004_CABGx6RKX5xDbFNVKpis7vcjLWGCgXdfHbiRDHvZWKGDYV5Amailgma_"; type="multipart/alternative"', 'MIME-Version': '1.0'}
# from  0000zzzz099@gmail.com
# return
# reply
# {'Subject': 'Você tem um pacote aguardando entrega', 'Date': 'Tue, 20 Feb 2024 12:36:23 +0000', 'From': 'Soula Mohamadi <Mohamadi-Tamado.Soula@ac-mayotte.fr>', 'Message-ID': '<5096-65d49d00-33-718d210@115831016>', 'Received-SPF': 'None (mx1.ua.pt: no sender authenticity information  available from domain of postmaster@mtaout2.ac-mayotte.fr)  identity=helo; client-ip=193.55.5.84; receiver=mx1.ua.pt;  envelope-from="Mohamadi-Tamado.Soula@ac-mayotte.fr";  x-sender="postmaster@mtaout2.ac-mayotte.fr";  x-conformance=spf_only', 'Content-Type': 'multipart/alternative; boundary="_000_509665d49d0033718d210115831016_"', 'MIME-Version': '1.0'}
# from  mohamadi-tamado.soula@ac-mayotte.fr
# return
# reply
# {'Subject': 'Acknowledgment Receipt: Thank You for Your Order #XCXOK5O', 'Date': 'Fri, 16 Feb 2024 18:30:20 +0530', 'From': 'Tera M Kerr <alicecontreras1348@gmail.com>', 'To': 'yadayada84 <yadayada84@hotmail.com>', 'Return-Path': 'alicecontreras1348@gmail.com', 'Message-ID': '<65cf5c72.050a0220.3c879.7c96@mx.google.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of gmail.com designates 209.85.128.45 as permitted sender) receiver=protection.outlook.com; client-ip=209.85.128.45; helo=mail-wm1-f45.google.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 209.85.128.45) smtp.mailfrom=gmail.com; dkim=pass (signature was verified) header.d=gmail.com;dmarc=pass action=none header.from=gmail.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="5Zg=_DNkaNo56TBqNkFRa5LgewR5QgNBRG"', 'MIME-Version': '1.0'}
# from  alicecontreras1348@gmail.com
# return  alicecontreras1348@gmail.com
# reply
# {'Subject': 'Thank you for your purchase!', 'Date': 'Thu, 04 Jan 2024 19:41:34 +0000', 'From': 'Zara Home <noreply@notice.mailservice-im.com>', 'To': 'Constança Mendonça <constanca@ua.pt>', 'Reply-To': 'Zara Home <support@owbuilder.com>', 'Message-ID': '<98C96134-A4B4-A8EB-F376-132C0124D68A>', 'Received-SPF': 'None (mx1.ua.pt: no sender authenticity information  available from domain of  postmaster@mail-sgdm-235-108.aliyun.com) identity=helo;  client-ip=47.88.235.108; receiver=mx1.ua.pt;  envelope-from="noreply@notice.mailservice-im.com";  x-sender="postmaster@mail-sgdm-235-108.aliyun.com";  x-conformance=spf_only', 'Content-Type': 'multipart/alternative; boundary="_000_98C96134A4B4A8EBF376132C0124D68A_"', 'MIME-Version': '1.0'}
# from  noreply@notice.mailservice-im.com
# return
# reply  support@owbuilder.com
# {'Subject': 'Confirmation... ', 'Date': 'Sat, 16 Sep 2023 18:39:34 +0000', 'From': '--Heated Scarf | Limited-- <receipts@lawpay.com>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'bounces+21190296-rixtykcrcc@30755.theslategroup.com', 'Message-ID': '<93b43f69-0c86-48a1-9597-50a075497067@BN8NAM11FT005.eop-nam11.prod.protection.outlook.com>', 'Received-SPF': 'TempError (protection.outlook.com: error in processing during lookup of 30755.theslategroup.com: DNS Timeout)', 'Authentication-Results': 'spf=temperror (sender IP is 187.85.68.211) smtp.mailfrom=30755.theslategroup.com; dkim=none (message not signed) header.d=none;dmarc=fail action=none header.from=lawpay.com;', 'Content-Type': 'multipart/alternative; boundary="9f6043d99345681b258c29be4cbc16957be87dd5e599de013ea8adc34b8b"', 'MIME-Version': '1.0'}
# from  receipts@lawpay.com
# return  bounces+21190296-rixtykcrcc@30755.theslategroup.com
# reply
# {'Subject': 'Número do Incidente #91672', 'Date': 'Thu, 30 Nov 2023 12:28:56 +0000', 'From': 'Anabela Pereira <anabelapereira@ua.pt>', 'Message-ID': '<VI1PR02MB579160DBC0084183661A6E10D882A@VI1PR02MB5791.eurprd02.prod.outlook.com>', 'Received-SPF': 'Pass (mx02.ua.pt: domain of anabelapereira@ua.pt designates 104.47.51.169 as permitted sender) receiver=mx02.ua.pt; client-ip=104.47.51.169; helo=EUR03-DBA-obe.outbound.protection.outlook.com;', 'Content-Type': 'multipart/alternative; boundary="_000_VI1PR02MB579160DBC0084183661A6E10D882AVI1PR02MB5791eurp_"', 'MIME-Version': '1.0'}
# from  anabelapereira@ua.pt
# return
# reply
# {'Subject': '', 'Date': 'Wed, 15 Nov 2023 09:59:18 +0000', 'From': '"Prof. Dr. João Miguel Dias" <managementmail20@gmail.com>', 'To': 'Suresh Kumar <suresh@ua.pt>', 'Message-ID': ' \t<CAGWDO0V67ybq9-tk2CwKWXJqLd-qa1brfqmAKq9sg9B8qn-QAw@mail.gmail.com>', 'Received-SPF': 'None (mx3.ua.pt: no sender authenticity information  available from domain of postmaster@mail-oo1-f53.google.com)  identity=helo; client-ip=209.85.161.53; receiver=mx3.ua.pt;  envelope-from="managementmail20@gmail.com";  x-sender="postmaster@mail-oo1-f53.google.com";  x-conformance=spf_only', 'Content-Type': 'multipart/alternative; boundary="_000_CAGWDO0V67ybq9tk2CwKWXJqLdqa1brfqmAKq9sg9B8qnQAwmailgma_"', 'MIME-Version': '1.0'}
# from  managementmail20@gmail.com
# return
# reply
# {'Subject': 'Your Detailed Electronic Invoice is Ready #2GG5Q', 'Date': 'Tue, 20 Feb 2024 22:53:39 +0530', 'From': 'Randall L Barge <nanniechoiuayj29@gmail.com>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'nanniechoiuayj29@gmail.com', 'Message-ID': '<65d4e022.170a0220.10862.4664@mx.google.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of gmail.com designates 209.85.208.53 as permitted sender) receiver=protection.outlook.com; client-ip=209.85.208.53; helo=mail-ed1-f53.google.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 209.85.208.53) smtp.mailfrom=gmail.com; dkim=pass (signature was verified) header.d=gmail.com;dmarc=pass action=none header.from=gmail.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="tHfrF=_1PhbxvS9ypH9VMmGESPDvFVgJxe"', 'MIME-Version': '1.0'}
# from  nanniechoiuayj29@gmail.com
# return  nanniechoiuayj29@gmail.com
# reply
# {'Subject': 'Tаx гeturn infоrmation - Stаtement stаtus avаilable [ID - 2931429806]', 'Date': 'Mon, 13 Nov 2023 06:15:14 -0800', 'From': '"IRS Gov." <donot_reply.deliverymessage-7mfyqznpj2vremct4@baguselectric.com>', 'To': 'undisclosed-recipients:;', 'Return-Path': 'donot_reply.deliverymessage-7mfyqznpj2vremct4@baguselectric.com', 'Message-ID': ' <CADMHc5qWaBqZaP_QhmZzXXEvqJsvwqcu79nShMP-EOUd3CqyYQ@mail.gmail.com>', 'Received-SPF': 'SoftFail (protection.outlook.com: domain of transitioning baguselectric.com discourages use of 209.85.160.48 as permitted sender)', 'Authentication-Results': 'spf=softfail (sender IP is 209.85.160.48) smtp.mailfrom=baguselectric.com; dkim=pass (signature was verified) header.d=baguselectric-com.20230601.gappssmtp.com;dmarc=none action=none header.from=baguselectric.com;', 'Content-Type': 'multipart/mixed; boundary="000000000000224b72060a094d2e"', 'MIME-Version': '1.0'}
# from  donot_reply.deliverymessage-7mfyqznpj2vremct4@baguselectric.com
# return  donot_reply.deliverymessage-7mfyqznpj2vremct4@baguselectric.com
# reply
# {'Subject': 'Congratulations!You have won an Apple Vision Pro--165', 'Date': 'Sat, 17 Feb 2024 23:59:24 +0000', 'From': 'A p p l e® Vision Pro--165 <info@udina.li>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'info@jwhzgzo.udina.li', 'Message-ID': '<54560fcd-f662-4395-81e1-20d18997d595@DB1PEPF000509F9.eurprd02.prod.outlook.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of jwhzgzo.udina.li designates 149.18.118.7 as permitted sender) receiver=protection.outlook.com; client-ip=149.18.118.7; helo=blogozine.net; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 149.18.118.7) smtp.mailfrom=jwhzgzo.udina.li; dkim=none (message not signed) header.d=none;dmarc=pass action=none header.from=udina.li;compauth=pass reason=100', 'Content-Type': 'text/html; charset="utf-8"', 'MIME-Version': '1.0'}
# from  info@udina.li
# return  info@jwhzgzo.udina.li
# reply
# {'Subject': 'Notice of Facebook Sponsored Stories Class Action Settlement Approval Hearing – Read Carefully as this Notice may affect your rights', 'Date': 'Tue, 16 Jan 2024 20:57:10 +0000', 'From': 'MNP LTD <no.reply@mnp.ca>', 'To': 'cris.cerqueira@utoronto.ca', 'Return-Path': 'cris.cerqueira+SRS=DTfCV=I2=utoronto.onmicrosoft.com=bounces@alumni.utoronto.ca', 'Reply-To': 'MNP LTD <no.reply@mnp.ca>', 'Message-ID': '<4b18c024f51870644334372bd.3a6e1a7bc1.20240116205657.678d314b9a.6beaf65a@mail210.atl241.mcsv.net>', 'Received-SPF': 'Pass (protection.outlook.com: domain of alumni.utoronto.ca designates 40.107.115.105 as permitted sender) receiver=protection.outlook.com; client-ip=40.107.115.105; helo=CAN01-YT3-obe.outbound.protection.outlook.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 40.107.115.105) smtp.mailfrom=alumni.utoronto.ca; dkim=pass (signature was verified) header.d=alumutoronto.onmicrosoft.com;dmarc=pass action=none header.from=mnp.ca;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="_----------=_MCPart_1791531127"', 'MIME-Version': '1.0'}
# from  no.reply@mnp.ca
# return  bounces@alumni.utoronto.ca
# reply  no.reply@mnp.ca
# {'Subject': 'Security Breach: Your Device is infected With (63) Viruses__195', 'Date': 'Wed, 21 Feb 2024 21:36:50 +0000', 'From': 'Noɾtoᥒ®__195 <info@udina.li>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'info@yftqsehjs.udina.li', 'Message-ID': '<fbd88216-f29f-41e2-bf5b-fea78b5bed6a@MW2NAM10FT069.eop-nam10.prod.protection.outlook.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of yftqsehjs.udina.li designates 154.6.28.206 as permitted sender) receiver=protection.outlook.com; client-ip=154.6.28.206; helo=hudsonrivervalley.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 154.6.28.206) smtp.mailfrom=yftqsehjs.udina.li; dkim=fail (no key for signature) header.d=mxtfy.li;dmarc=pass action=none header.from=udina.li;compauth=pass reason=100', 'Content-Type': 'text/html; charset="utf-8"', 'MIME-Version': '1.0'}
# from  info@udina.li
# return  info@yftqsehjs.udina.li
# reply
# {'Subject': 'Atenção - email suspeito', 'Date': 'Mon, 06 Nov 2023 15:07:27 +0000', 'From': 'Luís Pinheiro <lmp@ua.pt>', 'To': 'Luís Carvalheiro <lcarvalheiro@ua.pt>', 'Message-ID': '<a7618c07ad6345fba0706006631a56e7@ua.pt>', 'Content-Type': 'multipart/related; boundary="_005_a7618c07ad6345fba0706006631a56e7uapt_"; type="text/html"', 'MIME-Version': '1.0'}
# from  lmp@ua.pt
# return
# reply
# {'Subject': 'Feedback Alumni: emoções, aprendizagens e experiências vividas...', 'Date': 'Wed, 20 Sep 2023 14:11:27 +0000', 'From': 'Innovation Experience <innovationexperience@a.kajabimail.net>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'bounce+v2+342d62.d654.1695478287.BAABAAXkAMIZRGA22sxOcIdmOd81BpqvYw~yadayada84=hotmail.com@a.kajabimail.net', 'Reply-To': 'info@innovationexperience.org', 'Message-ID': '<20230920141127.5e85e675ee27b903@a.kajabimail.net>', 'Received-SPF': 'Pass (protection.outlook.com: domain of a.kajabimail.net designates 143.55.229.214 as permitted sender) receiver=protection.outlook.com; client-ip=143.55.229.214; helo=mail229-214.static.kajabi-mail.net; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 143.55.229.214) smtp.mailfrom=a.kajabimail.net; dkim=pass (signature was verified) header.d=a.kajabimail.net;dmarc=pass action=none header.from=a.kajabimail.net;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="e2e7cfa0d8ede236a065265c03590ab2f112c01e09548bf6df333ebee859"', 'MIME-Version': '1.0'}
# from  innovationexperience@a.kajabimail.net
# return  hotmail.com@a.kajabimail.net
# reply  info@innovationexperience.org
# {'Subject': 'RE: Your Order', 'Date': 'Sat, 10 Feb 2024 02:03:44 +0000', 'From': 'Couples Choices <hello@coupleschoices.com>', 'To': 'yadayada84@hotmail.com', 'Return-Path': '  bounces+5423847-bee5-yadayada84=hotmail.com@hello.coupleschoices.com', 'Message-ID': '<PVXaw0EbRZmIwdq9K65sFA@geopod-ismtpd-8>', 'Received-SPF': 'Pass (protection.outlook.com: domain of hello.coupleschoices.com designates 168.245.125.63 as permitted sender) receiver=protection.outlook.com; client-ip=168.245.125.63; helo=o1401.shared.klaviyomail.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 168.245.125.63) smtp.mailfrom=hello.coupleschoices.com; dkim=pass (signature was verified) header.d=coupleschoices.com;dmarc=pass action=none header.from=coupleschoices.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="9cfec2d846af331f33cc1b9bfbcee5a615af0ca2585fe5ff7a266b6ac99c"', 'MIME-Version': '1.0'}
# from  hello@coupleschoices.com
# return  hotmail.com@hello.coupleschoices.com
# reply
# {'Subject': 'Internal Memo: Ua Staff Employment Termination Notice ', 'Date': 'Mon, 09 Oct 2023 09:40:33 +0000', 'From': 'Ua HR Department <hr@wirrco.com>', 'To': 'anamargarida@ua.pt', 'Return-Path': 'hr@wirrco.com', 'Message-ID': '<d35f94a2-933d-7f3f-1975-9669c7c1cb96@wirrco.com>', 'Received-SPF': 'Pass (mx3.ua.pt: domain of hr@wirrco.com designates  194.156.90.198 as permitted sender) identity=mailfrom;  client-ip=194.156.90.198; receiver=mx3.ua.pt;  envelope-from="hr@wirrco.com"; x-sender="hr@wirrco.com";  x-conformance=spf_only; x-record-type="v=spf1";  x-record-text="v=spf1 a mx ptr a:wirrco.com  ip4:194.156.90.0/24 ?all"', 'Authentication-Results': 'mx3.ua.pt; spf=Pass smtp.mailfrom=hr@wirrco.com; spf=None smtp.helo=postmaster@mta0.wirrco.com; dkim=pass (signature verified) header.i=hr@wirrco.com', 'Content-Type': 'text/html; charset="utf-8"', 'MIME-Version': '1.0'}
# from  hr@wirrco.com
# return  hr@wirrco.com
# reply
# {'Subject': 'notifications', 'Date': 'Tue, 03 Oct 2023 21:35:04 +0000', 'From': 'Kohls*Confirmation <noreply@lawnprosoftware.com>', 'To': 'virginiaross882@yahoo.com', 'Return-Path': 'Y6kiOz8@84708.bongo4u.com', 'Reply-To': 'Kohls*Confirmation <alieydhdyzgys@yahoo.com>', 'Message-ID': '<31143562.20231003213504.651c8908225e23.49685977@mail178-175.suw51.mandrillapp.com>', 'Received-SPF': 'Fail (protection.outlook.com: domain of 84708.bongo4u.com does not designate 187.85.68.81 as permitted sender) receiver=protection.outlook.com; client-ip=187.85.68.81; helo=81-68-85-187.kdimjsargdgspditbvqy.jbvhiuvkdvsn.vbn.qv;', 'Authentication-Results': 'spf=fail (sender IP is 187.85.68.81) smtp.mailfrom=84708.bongo4u.com; dkim=pass (signature was verified) header.d=lawnprosoftware.com;dmarc=pass action=none header.from=lawnprosoftware.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="_av-LMizdi46pAga1oOCXfuUlQ"', 'MIME-Version': '1.0'}
# from  noreply@lawnprosoftware.com
# return  y6kioz8@84708.bongo4u.com
# reply  alieydhdyzgys@yahoo.com
# {'Subject': 'Sit Comfortably, Anywhere, Limited Time Promo: 50% Off Klaudena! J8', 'Date': 'Wed, 31 Jan 2024 11:55:47 +0100', 'From': 'Klaudena Seat Cushion 82 <ahmab.dogcom.7@gmail.com>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'ahmab.dogcom.7@gmail.com', 'Message-ID': ' <CAL6PuPxUT57Mvc=O_CHtt5XzJ4g98D0ofUmX+afatmm3JiGDrg@mail.gmail.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of gmail.com designates 209.85.219.47 as permitted sender) receiver=protection.outlook.com; client-ip=209.85.219.47; helo=mail-qv1-f47.google.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 209.85.219.47) smtp.mailfrom=gmail.com; dkim=pass (signature was verified) header.d=gmail.com;dmarc=pass action=none header.from=gmail.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="00000000000047c56206103bb955"', 'MIME-Version': '1.0'}
# from  ahmab.dogcom.7@gmail.com
# return  ahmab.dogcom.7@gmail.com
# reply
# {'Subject': 'Drop 28 lbs. in One Month--369', 'Date': 'Sun, 18 Feb 2024 20:51:46 +0000', 'From': 'ABC Shark Tank--369 <info@udina.li>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'info@dvsafdypw.udina.li', 'Message-ID': '<fe14376b-9716-4dd8-b065-97e070b594f7@AM7EUR06FT032.eop-eur06.prod.protection.outlook.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of dvsafdypw.udina.li designates 154.6.59.194 as permitted sender) receiver=protection.outlook.com; client-ip=154.6.59.194; helo=mail.trumpetexercises.net; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 154.6.59.194) smtp.mailfrom=dvsafdypw.udina.li; dkim=fail (no key for signature) header.d=ellhlmm.li;dmarc=pass action=none header.from=udina.li;compauth=pass reason=100', 'Content-Type': 'text/html; charset="utf-8"', 'MIME-Version': '1.0'}
# from  info@udina.li
# return  info@dvsafdypw.udina.li
# reply
# {'Subject': '3rd attemِpt T0 Conِtаct YOU, Confirmаtion Receipt#|CJT', 'Date': 'Thu, 21 Dec 2023 11:24:57 +0100', 'From': 'SainsbuِrysِConfِirmِation!|ZSG <laundryalhawar@gmail.com>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'laundryalhawar@gmail.com', 'Message-ID': ' <CAM2utCzbLGBQpKzGDYBqErvLwNSBPV=SYuRNOBHQ_sMP7FJYBA@mail.gmail.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of gmail.com designates 209.85.218.49 as permitted sender) receiver=protection.outlook.com; client-ip=209.85.218.49; helo=mail-ej1-f49.google.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 209.85.218.49) smtp.mailfrom=gmail.com; dkim=pass (signature was verified) header.d=gmail.com;dmarc=pass action=none header.from=gmail.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="0000000000009688e6060d028360"', 'MIME-Version': '1.0'}
# from  laundryalhawar@gmail.com
# return  laundryalhawar@gmail.com
# reply
# {'Subject': 'Fwd: Número do Incidente #91672', 'Date': 'Thu, 30 Nov 2023 12:35:01 +0000', 'From': 'Teresa Rocha Santos <ter.alex@ua.pt>', 'To': 'Anabela Pereira <anabela.pereira@ua.pt>', 'Message-ID': '<2ACF2BC8-430A-468C-B39D-EE7ABE9B6350@ua.pt>', 'Content-Type': 'text/html; charset="utf-8"', 'MIME-Version': '1.0'}
# from  ter.alex@ua.pt
# return
# reply
# {'Subject': 'Confirm subscription to Accepted Marketing', 'Date': 'Tue, 26 Dec 2023 19:12:58 +0000', 'From': 'Banco Montepio <admin@m24empresas.xyz>', 'To': 'João Raio <joaopedroraio@ua.pt>', 'Message-ID': '<20231226191258.7c7eef7a813bfa0a@receiptful.com>', 'Received-SPF': 'None (mx1.ua.pt: no sender authenticity information  available from domain of  postmaster@a119.a0ece303.use4.send.mailgun.net)  identity=helo; client-ip=198.244.48.119; receiver=mx1.ua.pt;  envelope-from="bounce+9212de.84918-joaopedroraio=ua.pt@receiptful.com";  x-sender="postmaster@a119.a0ece303.use4.send.mailgun.net";  x-conformance=spf_only', 'Authentication-Results': 'spf=permerror (sender IP is 193.136.173.5) smtp.mailfrom=receiptful.com; dkim=pass (signature was verified) header.d=receiptful.com;dmarc=none action=none header.from=m24empresas.xyz;', 'Content-Type': 'multipart/alternative; boundary="_000_202312261912587c7eef7a813bfa0areceiptfulcom_"', 'MIME-Version': '1.0'}
# from  admin@m24empresas.xyz
# return
# reply
# {'Subject': '3rd attempt To Contact YOU, You have won an TemบPallets, confirm your receipt #JFKM', 'Date': 'Sat, 09 Dec 2023 09:53:01 +0100', 'From': 'TemบDepartment Us <ariunsuld100@gmail.com>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'ariunsuld100@gmail.com', 'Message-ID': ' <CAL2iHO+maTqX6+BDm4M9UrFNzy7mibd93dtR9s32F9fEsOMkqg@mail.gmail.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of gmail.com designates 209.85.208.177 as permitted sender) receiver=protection.outlook.com; client-ip=209.85.208.177; helo=mail-lj1-f177.google.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 209.85.208.177) smtp.mailfrom=gmail.com; dkim=pass (signature was verified) header.d=gmail.com;dmarc=pass action=none header.from=gmail.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="000000000000b74a8d060c0fd456"', 'MIME-Version': '1.0'}
# from  ariunsuld100@gmail.com
# return  ariunsuld100@gmail.com
# reply
# {'Subject': 'sent On:  Wednesday, October 11, 2023 10:40 a.m.', 'Date': 'Wed, 11 Oct 2023 11:13:04 -0500', 'From': 'JAMES BARLOWE for yadayada84 <mohsaiid@live.com>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'mohsaiid@live.com', 'Reply-To': 'jamesbarlowe112@gmail.com', 'Message-ID': '<AM7P192MB0657BDC420D3A2547553A2E0BFCCA@AM7P192MB0657.EURP192.PROD.OUTLOOK.COM>', 'Received-SPF': 'Pass (protection.outlook.com: domain of live.com designates 40.92.49.15 as permitted sender) receiver=protection.outlook.com; client-ip=40.92.49.15; helo=EUR02-AM0-obe.outbound.protection.outlook.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 40.92.49.15) smtp.mailfrom=live.com; dkim=pass (signature was verified) header.d=live.com;dmarc=pass action=none header.from=live.com;compauth=pass reason=100', 'Content-Type': 'text/html', 'MIME-Version': '1.0'}
# from  mohsaiid@live.com
# return  mohsaiid@live.com
# reply  jamesbarlowe112@gmail.com
# {'Subject': 'IT-Helpdesk ( Expiração de senha )', 'Date': 'Mon, 19 Feb 2024 09:05:54 +0000', 'From': 'Nurul Aqmar Razali <nurulaqmar@ijn.com.my>', 'Reply-To': 'Nurul Aqmar Razali <nurulaqmar@ijn.com.my>', 'Message-ID': '<9c347fea3b1047e292273c7d220a9329@ijn.com.my>', 'Received-SPF': 'None (mx4.ua.pt: no sender authenticity information  available from domain of postmaster@mail.ijn.com.my)  identity=helo; client-ip=103.111.74.220; receiver=mx4.ua.pt;  envelope-from="nurulaqmar@ijn.com.my";  x-sender="postmaster@mail.ijn.com.my"; x-conformance=spf_only', 'Content-Type': 'multipart/alternative; boundary="_000_9c347fea3b1047e292273c7d220a9329ijncommy_"', 'MIME-Version': '1.0'}
# from  nurulaqmar@ijn.com.my
# return
# reply  nurulaqmar@ijn.com.my
# {'Subject': 'LEITURA 🚩 URGENTE🚩', 'Date': 'Sat, 13 Jan 2024 12:41:39 +0000', 'From': 'CIBERCRIMINALIDADE <fernandogracia0078@gmail.com>', 'Message-ID': '<a40965e8-c849-46c3-856e-545653fd3b2f@gmail.com>', 'Content-Type': 'multipart/mixed; boundary="_278BD4D6-95F6-FF4B-B978-34424B4739A6_"', 'MIME-Version': '1.0'}
# from  fernandogracia0078@gmail.com
# return
# reply
# {'Subject': 'RE: Services - Your Account Status Is Hold And All Your Last Order, Thursday 12 October 2023. Ticket#5KVBD15MXVW', 'Date': 'Fri, 13 Oct 2023 00:57:48 +0000', 'From': "Prime's | Support Service <IMTFIZi4Rmk2cNwreUXTYGuEvgkSob9p3yPG10CaUIVGnTGLmF0ixnh@dyyxl.onmicrosoft.com>", 'To': 'yadayada84@hotmail.com', 'Return-Path': ' IMTFIZi4Rmk2cNwreUXTYGuEvgkSob9p3yPG10CaUIVGnTGLmF0ixnh@dyyxl.onmicrosoft.com', 'Message-ID': '<f02205b6-f7df-4795-8175-882867aaa240@dyyxl.onmicrosoft.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of dyyxl.onmicrosoft.com designates 40.107.237.54 as permitted sender) receiver=protection.outlook.com; client-ip=40.107.237.54; helo=NAM12-BN8-obe.outbound.protection.outlook.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 40.107.237.54) smtp.mailfrom=dyyxl.onmicrosoft.com; dkim=none (message not signed) header.d=none;dmarc=bestguesspass action=none header.from=dyyxl.onmicrosoft.com;compauth=pass reason=109', 'Content-Type': 'application/pdf; name="7-70731.pdf"', 'MIME-Version': '1.0'}
# from  imtfizi4rmk2cnwreuxtyguevgksob9p3ypg10cauivgntglmf0ixnh@dyyxl.onmicrosoft.com
# return  imtfizi4rmk2cnwreuxtyguevgksob9p3ypg10cauivgntglmf0ixnh@dyyxl.onmicrosoft.com
# reply
# {'Subject': 'Fatty Liver Cure Discovered in Ancient rome ? Q8', 'Date': 'Wed, 08 Nov 2023 11:08:18 +0100', 'From': 'Toxic Liver Qz2l <cangelbatu@gmail.com>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'cangelbatu@gmail.com', 'Message-ID': ' <CACYLc1zCR5HbB3zq0Dcb_Mc6WUi6rxikLocOzei=cXK=RMLX0A@mail.gmail.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of gmail.com designates 209.85.208.46 as permitted sender) receiver=protection.outlook.com; client-ip=209.85.208.46; helo=mail-ed1-f46.google.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 209.85.208.46) smtp.mailfrom=gmail.com; dkim=pass (signature was verified) header.d=gmail.com;dmarc=pass action=none header.from=gmail.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="000000000000d305d70609a14476"', 'MIME-Version': '1.0'}
# from  cangelbatu@gmail.com
# return  cangelbatu@gmail.com
# reply
# {'Subject': 'Your Apple Account has been Disabled and Temporary Hold All Your Subscriptions, Monday 12 November 2023. Reff ARVMP1AERX.', 'Date': 'Mon, 13 Nov 2023 18:37:14 +0100', 'From': 'App Stoܿre <mail-delveryreportsds18@re.balifamilyparadisetours.com>', 'To': 'app@iclouds.com', 'Return-Path': 'mail-delveryreportsds18@re.balifamilyparadisetours.com', 'Message-ID': ' <aaky8RwWRifMsUrMbVpEt7f8ftaSoxhqnQo7im6vJ30@mail-atf-9608.e.boldpac.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of re.balifamilyparadisetours.com designates 40.107.96.56 as permitted sender) receiver=protection.outlook.com; client-ip=40.107.96.56; helo=NAM02-SN1-obe.outbound.protection.outlook.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 40.107.96.56) smtp.mailfrom=re.balifamilyparadisetours.com; dkim=none (message not signed) header.d=none;dmarc=bestguesspass action=none header.from=re.balifamilyparadisetours.com;compauth=pass reason=109', 'Content-Type': 'multipart/mixed; boundary="_----------=_MCPart_504679"', 'MIME-Version': '1.0'}
# from  mail-delveryreportsds18@re.balifamilyparadisetours.com
# return  mail-delveryreportsds18@re.balifamilyparadisetours.com
# reply
# {'Subject': 'Your package delivery Notification ID#3430900-371', 'Date': 'Fri, 16 Feb 2024 19:08:42 +0000', 'From': 'UPS® ID#3430900 <info@udina.li>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'info@rhmbnjz.udina.li', 'Message-ID': '<48e2a41c-0d57-40fc-b434-f887920896fc@AM7EUR06FT067.eop-eur06.prod.protection.outlook.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of rhmbnjz.udina.li designates 154.6.59.47 as permitted sender) receiver=protection.outlook.com; client-ip=154.6.59.47; helo=mail.meteorites.tv; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 154.6.59.47) smtp.mailfrom=rhmbnjz.udina.li; dkim=fail (no key for signature) header.d=clovi.li;dmarc=pass action=none header.from=udina.li;compauth=pass reason=100', 'Content-Type': 'text/html; charset="utf-8"', 'MIME-Version': '1.0'}
# from  info@udina.li
# return  info@rhmbnjz.udina.li
# reply
# {'Subject': 'confirmation', 'Date': 'Sun, 01 Oct 2023 12:11:12 +0000', 'From': '"nocturnglases.." <noreply@lawnprosoftware.com>', 'To': 'axeldylan866@yahoo.com', 'Return-Path': 'bounces+9699232-xjilgwmriq@25657.aip-benefits.org', 'Reply-To': '"nocturnglases.." <testaffter1245@gmail.com>', 'Message-ID': '<31143562.20231001121112.651961e0ec6168.04108340@mail178-175.suw51.mandrillapp.com>', 'Received-SPF': 'TempError (protection.outlook.com: error in processing during lookup of 25657.aip-benefits.org: DNS Timeout)', 'Authentication-Results': 'spf=temperror (sender IP is 187.85.68.92) smtp.mailfrom=25657.aip-benefits.org; dkim=pass (signature was verified) header.d=lawnprosoftware.com;dmarc=pass action=none header.from=lawnprosoftware.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="_av-21pRbLybZKaZlilHpdrCVw"', 'MIME-Version': '1.0'}
# from  noreply@lawnprosoftware.com
# return  bounces+9699232-xjilgwmriq@25657.aip-benefits.org
# reply  testaffter1245@gmail.com
# {'Subject': 'Banco Montepio - Conta bloqueada', 'Date': 'Fri, 03 Nov 2023 09:25:00 +0000', 'From': 'Montepio24 <seguranca@m24-app.com>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'bounces+2693180-9356-yadayada84=hotmail.com@m.dripemail2.com', 'Message-ID': '<EZkUdUCWQf-k6grr7dU-_w@geopod-ismtpd-2>', 'Received-SPF': 'Pass (protection.outlook.com: domain of m.dripemail2.com designates 149.72.153.29 as permitted sender) receiver=protection.outlook.com; client-ip=149.72.153.29; helo=o26.ptr649.driptransact2.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 149.72.153.29) smtp.mailfrom=m.dripemail2.com; dkim=pass (signature was verified) header.d=dripemail2.com;dmarc=none action=none header.from=m24-app.com;compauth=fail reason=001', 'Content-Type': 'multipart/alternative; boundary="9d09883caf59e305c4fdfed4f9164dd88c4befd88811b558f05811c5d75b"', 'MIME-Version': '1.0'}
# from  seguranca@m24-app.com
# return  hotmail.com@m.dripemail2.com
# reply
# {'Subject': '', 'Date': 'Wed, 15 Nov 2023 11:41:54 +0000', 'From': '"Prof. Dr. Armando Jorge Domingues de Silvestre" <hanmingfang26@gmail.com>', 'To': 'Márcia Neves <mcneves@ua.pt>', 'Message-ID': ' \t<CAJChZnsNYDVS0LsXb0yT8z6dxNuKROOtmdPk4tk+PBQVMk_VsQ@mail.gmail.com>', 'Received-SPF': 'None (mx4.ua.pt: no sender authenticity information  available from domain of postmaster@mail-ed1-f48.google.com)  identity=helo; client-ip=209.85.208.48; receiver=mx4.ua.pt;  envelope-from="hanmingfang26@gmail.com";  x-sender="postmaster@mail-ed1-f48.google.com";  x-conformance=spf_only', 'Content-Type': 'multipart/alternative; boundary="_000_CAJChZnsNYDVS0LsXb0yT8z6dxNuKROOtmdPk4tkPBQVMkVsQmailgm_"', 'MIME-Version': '1.0'}
# from  hanmingfang26@gmail.com
# return
# reply
# {'Subject': 'Check your account statement#13266191OPN', 'Date': 'Fri, 28 Jul 2023 23:07:37 +0530', 'From': '"Camille T. Thomas" <reyhtrhtrhy@gmail.com>', 'To': 'yadayada84 <yadayada84@hotmail.com>', 'Return-Path': 'reyhtrhtrhy@gmail.com', 'Message-ID': '<64c3fce3.e90a0220.2f691.5766@mx.google.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of gmail.com designates 209.85.219.52 as permitted sender) receiver=protection.outlook.com; client-ip=209.85.219.52; helo=mail-qv1-f52.google.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 209.85.219.52) smtp.mailfrom=gmail.com; dkim=pass (signature was verified) header.d=gmail.com;dmarc=pass action=none header.from=gmail.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="4dr6J300sjTMT5UcdoLBt9ouBe=_XmWNVo"', 'MIME-Version': '1.0'}
# from  reyhtrhtrhy@gmail.com
# return  reyhtrhtrhy@gmail.com
# reply
# {'Subject': 'To tear us down', 'Date': 'Tue, 05 Dec 2023 23:49:26 +0000', 'From': '"SaniyamNurma.g.om.be.tova" <SaniyamNurma.g.om.be.tova@khoand0000.me>', 'To': 'Cristina c <yadayada84@hotmail.com>', 'Reply-To': '"SaniyamNurm.a.gombetova@gmail.com" <SaniyamNurm.a.gombetova@gmail.com>', 'Message-ID': '<E1rAfAM-00HQzM-28@server203.web-hosting.com>', 'Received-SPF': 'None (protection.outlook.com: server203.web-hosting.com does not designate permitted sender hosts)', 'Content-Type': 'multipart/mixed; boundary="_002_E1rAfAM00HQzM28server203webhostingcom_"', 'MIME-Version': '1.0'}
# from  saniyamnurma.g.om.be.tova@khoand0000.me
# return
# reply  saniyamnurm.a.gombetova@gmail.com
# {'Subject': 'Finanças - Apreensão de dinheiro e/ou valores depositados como forma de penhora.', 'Date': 'Tue, 30 Jan 2024 15:31:05 +0000', 'From': 'Rui Vitorino <rvitorino@ua.pt>', 'To': '"marisa.santos@timelink.pt" <marisa.santos@timelink.pt>', 'Message-ID': '<b05702d0b48b44bcb29c9d049335cfad@ua.pt>', 'Content-Type': 'multipart/alternative; boundary="_000_b05702d0b48b44bcb29c9d049335cfaduapt_"', 'MIME-Version': '1.0'}
# from  rvitorino@ua.pt
# return
# reply
# {'Subject': 'Aberrtura o procedimento co', 'Date': 'Tue, 27 Feb 2024 09:25:45 +0000', 'From': 'STIC-Geral <BBogisich@nafaa.id>', 'To': 'Secretaria dos sTIC <stic-secretaria@ua.pt>', 'Message-ID': '<05312f74-4fb3-4c9f-b4cb-ddc959be3fcc@nafaa.id>', 'Received-SPF': 'None (mx4.ua.pt: no sender authenticity information  available from domain of  postmaster@seagreen.cherry.relay.mailchannels.net)  identity=helo; client-ip=23.83.223.160; receiver=mx4.ua.pt;  envelope-from="BBogisich@nafaa.id";  x-sender="postmaster@seagreen.cherry.relay.mailchannels.net";  x-conformance=spf_only', 'Content-Type': 'multipart/mixed; boundary="_004_05312f744fb34c9fb4cbddc959be3fccnafaaid_"', 'MIME-Version': '1.0'}
# from  bbogisich@nafaa.id
# return
# reply
# {'Subject': ' We are not Responsible if You are Hacked After The Expiration Date--834', 'Date': 'Sun, 18 Feb 2024 18:38:01 +0000', 'From': 'MᥴAƒᥱᥱ Sᥙρρoɾt--834 <info@udina.li>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'info@hphsculei.udina.li', 'Message-ID': '<afaa8d03-757b-476f-a71e-0211275b8352@BL02EPF0001A102.namprd05.prod.outlook.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of hphsculei.udina.li designates 149.18.117.153 as permitted sender) receiver=protection.outlook.com; client-ip=149.18.117.153; helo=mail.rialto-bc.com.ua; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 149.18.117.153) smtp.mailfrom=hphsculei.udina.li; dkim=none (message not signed) header.d=none;dmarc=pass action=none header.from=udina.li;compauth=pass reason=100', 'Content-Type': 'text/html; charset="utf-8"', 'MIME-Version': '1.0'}
# from  info@udina.li
# return  info@hphsculei.udina.li
# reply
# {'Subject': 'A\u200cc\u200cti\u200con Re\u200cq\u200cu\u200cired : Y\u200cour Pr\u200cime Me\u200cmb\u200cer\u200cship st\u200catem\u200cent wa\u200cs en\u200cd\u200ced - Y\u200cour re\u200cne\u200cwal sch\u200ced\u200cul\u200ced on 25 Ja\u200cnua\u200cry, 2024. #AJPX-4923730.', 'Date': 'Thu, 25 Jan 2024 11:25:00 +0000', 'From': 'P\u200cr\u200cim\u200ce͏ <mailfrom-subdomail-sfjiiqzp1@kioo.co.ke>', 'To': '"vieira@det.ua.pt" <vieira@det.ua.pt>', 'Message-ID': '<a5a11155-0b27-b2bf-12c9-67c0661c065f@kioo.co.ke>', 'Content-Type': 'text/html; charset="utf-8"', 'MIME-Version': '1.0'}
# from  mailfrom-subdomail-sfjiiqzp1@kioo.co.ke
# return
# reply
# {'Subject': 'confirmation', 'Date': 'Fri, 29 Sep 2023 20:59:04 +0000', 'From': 'Dash Cam <noreply@lawnprosoftware.com>', 'To': 'lawtarobozra4575@yahoo.com', 'Return-Path': 'bounces+3179222-uidjyvadmo@00283.aip-benefits.org', 'Reply-To': 'Dash Cam <chadiabiar85@gmail.com>', 'Message-ID': '<31143562.20230929205904.65173a98ec8771.36066893@mail178-175.suw51.mandrillapp.com>', 'Received-SPF': 'TempError (protection.outlook.com: error in processing during lookup of 00283.aip-benefits.org: DNS Timeout)', 'Authentication-Results': 'spf=temperror (sender IP is 187.85.68.84) smtp.mailfrom=00283.aip-benefits.org; dkim=pass (signature was verified) header.d=lawnprosoftware.com;dmarc=pass action=none header.from=lawnprosoftware.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="_av-Bnk-EGzghKI7nvNlmhubfQ"', 'MIME-Version': '1.0'}
# from  noreply@lawnprosoftware.com
# return  bounces+3179222-uidjyvadmo@00283.aip-benefits.org
# reply  chadiabiar85@gmail.com
# {'Subject': 'Congratulations! You Have Been Selected__036', 'Date': 'Wed, 21 Feb 2024 21:31:15 +0000', 'From': 'Canadian Tire®__036 <info@udina.li>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'info@agzwwdweg.udina.li', 'Message-ID': '<a6e8de65-aae7-4eed-85c4-b7adfe83b5c4@MW2NAM10FT030.eop-nam10.prod.protection.outlook.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of agzwwdweg.udina.li designates 154.6.30.21 as permitted sender) receiver=protection.outlook.com; client-ip=154.6.30.21; helo=ekeynumber.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 154.6.30.21) smtp.mailfrom=agzwwdweg.udina.li; dkim=fail (no key for signature) header.d=pzxrj.li;dmarc=pass action=none header.from=udina.li;compauth=pass reason=100', 'Content-Type': 'text/html; charset="utf-8"', 'MIME-Version': '1.0'}
# from  info@udina.li
# return  info@agzwwdweg.udina.li
# reply
# {'Subject': 'Your order is on the way', 'Date': 'Sat, 06 Jan 2024 13:15:05 +0000', 'From': 'Zara Home <noreply@notice.mailservice-im.com>', 'To': 'Constança Mendonça <constanca@ua.pt>', 'Reply-To': 'Zara Home <support@owbuilder.com>', 'Message-ID': '<BA6A93E0-C056-B37F-41C3-F6986736E2DF>', 'Received-SPF': 'None (mx1.ua.pt: no sender authenticity information  available from domain of  postmaster@mail-sgdm-235-108.aliyun.com) identity=helo;  client-ip=47.88.235.108; receiver=mx1.ua.pt;  envelope-from="noreply@notice.mailservice-im.com";  x-sender="postmaster@mail-sgdm-235-108.aliyun.com";  x-conformance=spf_only', 'Content-Type': 'multipart/alternative; boundary="_000_BA6A93E0C056B37F41C3F6986736E2DF_"', 'MIME-Version': '1.0'}
# from  noreply@notice.mailservice-im.com
# return
# reply  support@owbuilder.com
# {'Subject': 'Ditch your old dirty ρillow for Derila! gG', 'Date': 'Thu, 21 Dec 2023 11:18:15 +0100', 'From': 'Derila Memory Foam ρillow ZX <midristmw@gmail.com>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'midristmw@gmail.com', 'Message-ID': ' <CA+xNPD5oGG8J4b53Toz-ia2-jqZOKZJDHKeuiwXRiOAr8njnrA@mail.gmail.com>', 'Received-SPF': 'Pass (protection.outlook.com: domain of gmail.com designates 209.85.208.181 as permitted sender) receiver=protection.outlook.com; client-ip=209.85.208.181; helo=mail-lj1-f181.google.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 209.85.208.181) smtp.mailfrom=gmail.com; dkim=pass (signature was verified) header.d=gmail.com;dmarc=pass action=none header.from=gmail.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="000000000000914cd3060d026b5a"', 'MIME-Version': '1.0'}
# from  midristmw@gmail.com
# return  midristmw@gmail.com
# reply
# {'Subject': 'Acompanhe a sua encomenda #577215117391', 'Date': 'Sun, 25 Feb 2024 08:33:48 +0000', 'From': 'Causse Barbara <Barbara.Causse@ac-mayotte.fr>', 'Message-ID': '<14aa-65dafb80-5-539cf280@22491724>', 'Received-SPF': 'None (mx1.ua.pt: no sender authenticity information  available from domain of postmaster@mtaout2.ac-mayotte.fr)  identity=helo; client-ip=193.55.5.84; receiver=mx1.ua.pt;  envelope-from="Barbara.Causse@ac-mayotte.fr";  x-sender="postmaster@mtaout2.ac-mayotte.fr";  x-conformance=spf_only', 'Content-Type': 'multipart/alternative; boundary="_000_14aa65dafb805539cf28022491724_"', 'MIME-Version': '1.0'}
# from  barbara.causse@ac-mayotte.fr
# return
# reply
# {'Subject': 'Your BLOOMDSA LLC receipt [#1611-7121]', 'Date': 'Thu, 04 Jan 2024 19:42:36 +0000', 'From': 'BLOOMDSA LLC <receipts+acct_1OOiDAHRyHNoHgjS@stripe.com>', 'To': 'Constança Mendonça <constanca@ua.pt>', 'Reply-To': 'BLOOMDSA LLC <support@bloomdsa.com>', 'Message-ID': '<0101018cd5ffbcfa-a5456e4b-ff78-47ee-a523-0584548a4e60-000000@us-west-2.amazonses.com>', 'Received-SPF': 'None (mx4.ua.pt: no sender authenticity information  available from domain of  postmaster@a62-28.smtp-out.us-west-2.amazonses.com)  identity=helo; client-ip=54.240.62.28; receiver=mx4.ua.pt;  envelope-from="0101018cd5ffbcfa-a5456e4b-ff78-47ee-a523-0584548a4e60-000000@bounce.stripe.com";  x-sender="postmaster@a62-28.smtp-out.us-west-2.amazonses.com";  x-conformance=spf_only', 'Content-Type': 'multipart/alternative; boundary="_000_0101018cd5ffbcfaa5456e4bff7847eea5230584548a4e60000000u_"', 'MIME-Version': '1.0'}
# from  receipts+acct_1ooidahryhnohgjs@stripe.com
# return
# reply  support@bloomdsa.com
# {'Subject': 'Re: Your BMO online banking access has been restrict=?UTF-8?Q?ed_on_September 19, 2023_(REF_#4CYHC8X).?=', 'Date': 'Tue, 19 Sep 2023 20:00:02 +0200', 'From': 'BMO=?UTF-8?Q?=E2=80=84B?==?UTF-8?Q?ank_?=Of=?UTF-8?Q?_Mon?=tr=?UTF-8?Q?e?=a=?UTF-8?Q?l_?= <MsDonahue@nwyrkorg.onmicrosoft.com>', 'To': 'You <User16509e1a27b306@16509e1a27b30a.bmo.com.au>', 'Return-Path': 'MsDonahue@nwyrkorg.onmicrosoft.com', 'Reply-To': 'BLOCKCHAIN <16509E1A27BBEC.0101.0.0.0.0.16316509E1A27BBED@16509E1A27BBEE.EXCHANGELABS.COM>, 16509E1A27BBEF.0101.0.0.0.0.16316509E1A27BBF0@16509E1A27BBF1.EXCHANGELABS.COM, 16509E1A27BBF2.0101.0.0.0.0.16316509E1A27BBF3@16509E1A27BBF4.EXCHANGELABS.COM', 'Message-ID': '<000102.0101.0.0.0.0.16316509E1A27BAC4@ShadowKhan>', 'Received-SPF': 'Pass (protection.outlook.com: domain of nwyrkorg.onmicrosoft.com designates 40.107.220.107 as permitted sender) receiver=protection.outlook.com; client-ip=40.107.220.107; helo=NAM11-CO1-obe.outbound.protection.outlook.com; pr=C', 'Authentication-Results': 'spf=pass (sender IP is 40.107.220.107) smtp.mailfrom=nwyrkorg.onmicrosoft.com; dkim=fail (no key for signature) header.d=nwyrkorg.onmicrosoft.com;dmarc=permerror action=none header.from=nwyrkorg.onmicrosoft.com;compauth=pass reason=130', 'Content-Type': 'multipart/related; boundary="b1_JOtBZ9gUq1uJMzhfhZM2WJ3Umh1uh8bLgj1iUCC4UM"', 'MIME-Version': '1.0'}
# from  msdonahue@nwyrkorg.onmicrosoft.com
# return  msdonahue@nwyrkorg.onmicrosoft.com
# reply  16509e1a27bbec.0101.0.0.0.0.16316509e1a27bbed@16509e1a27bbee.exchangelabs.com
# {'Subject': 'Universo: [IMPORTANTE] Atualização anual da sua conta.', 'Date': 'Sun, 26 Nov 2023 23:51:05 +0000', 'From': 'Universo <contact@lustrefauvex.com>', 'To': 'Isabel F Marques <isabel.ferreira@ua.pt>', 'Message-ID': ' \t<20231126235411.26108.1157741789.swift@lustrefauvex.activehosted.com>', 'Received-SPF': 'Pass (mx4.ua.pt: domain of  postmaster@s17.avl3.acemsrvc.com designates 192.92.97.211 as  permitted sender) identity=helo; client-ip=192.92.97.211;  receiver=mx4.ua.pt;  envelope-from="bounce-3520774-2-41907-isabel.ferreira=ua.pt@s17.avl3.acemsrvc.com";  x-sender="postmaster@s17.avl3.acemsrvc.com";  x-conformance=spf_only; x-record-type="v=spf1";  x-record-text="v=spf1 ip4:173.236.20.0/24 ip4:192.92.97.0/24  ip4:52.128.40.0/21 ip4:217.8.118.0/24 ip4:103.229.233.0/24  ~all"', 'Content-Type': 'multipart/alternative; boundary="_000_20231126235411261081157741789swiftlustrefauvexactivehos_"', 'MIME-Version': '1.0'}
# from  contact@lustrefauvex.com
# return
# reply
# {'Subject': ' Information about a current data incident involving your email address', 'Date': 'Mon, 27 Nov 2023 17:26:49 +0000', 'From': 'Springer Nature <no-reply@springernature.com>', 'To': 'Isabel F Marques <isabel.ferreira@ua.pt>', 'Reply-To': '"customerservice@springernature.com" <customerservice@springernature.com>', 'Message-ID': '<55.D4.22883.A54D4656@io.mta1vrest.cc.prd.sparkpost>', 'Received-SPF': 'None (mx1.ua.pt: no sender authenticity information  available from domain of  postmaster@mta-90-93.sparkpostmail.com) identity=helo;  client-ip=192.174.90.93; receiver=mx1.ua.pt;  envelope-from="msprvs1=19695PmYBetn5=bounces-17638@spmailtechnol.com";  x-sender="postmaster@mta-90-93.sparkpostmail.com";  x-conformance=spf_only', 'Content-Type': 'multipart/alternative; boundary="_000_55D422883A54D4656iomta1vrestccprdsparkpost_"', 'MIME-Version': '1.0'}
# from  no-reply@springernature.com
# return
# reply  customerservice@springernature.com
# {'Subject': 'Enjoy solar Iights forever, spend $0 on biIIs... ', 'Date': 'Sat, 16 Sep 2023 17:36:29 +0000', 'From': '--SoIar_Power_Light-- <receipts@lawpay.com>', 'To': 'yadayada84@hotmail.com', 'Return-Path': 'bounces+13460169-kqjzurvswx@40670.theslategroup.com', 'Message-ID': '<51d07cd0-e8ed-4a5d-a49d-360cfc84372b@SN1NAM02FT0003.eop-nam02.prod.protection.outlook.com>', 'Received-SPF': 'TempError (protection.outlook.com: error in processing during lookup of 40670.theslategroup.com: DNS Timeout)', 'Authentication-Results': 'spf=temperror (sender IP is 187.85.68.218) smtp.mailfrom=40670.theslategroup.com; dkim=none (message not signed) header.d=none;dmarc=fail action=none header.from=lawpay.com;', 'Content-Type': 'multipart/alternative; boundary="9f6043d99345681b258c29be4cbc16957be87dd5e599de013ea8adc34b8b"', 'MIME-Version': '1.0'}
# from  receipts@lawpay.com
# return  bounces+13460169-kqjzurvswx@40670.theslategroup.com
# reply
# {'Subject': 'A suspensão do fornecimento de eletricidade ocorrerá 48 horas (contrato 368968784809113)', 'Date': 'Mon, 06 Nov 2023 14:21:00 +0000', 'From': 'EDP-Clientes <mauro_ralves@golnet.com.br>', 'To': 'Apoio à plataforma Argus <cesam-argus@ua.pt>', 'Message-ID': '<04f9236359154b01acfd2e25835e9d84@EXCHANGE-2-B1.ua.pt>', 'Received-SPF': 'None (mx4.ua.pt: no sender authenticity information  available from domain of postmaster@canit.fasternet.com.br)  identity=helo; client-ip=200.187.80.65; receiver=mx4.ua.pt;  envelope-from="mauro_ralves@golnet.com.br";  x-sender="postmaster@canit.fasternet.com.br";  x-conformance=spf_only', 'Content-Type': 'text/html; charset="Windows-1252"', 'MIME-Version': '1.0'}
# from  mauro_ralves@golnet.com.br
# return
# reply
# {'Subject': 'notifications', 'Date': 'Tue, 03 Oct 2023 18:00:04 +0000', 'From': '"kohls.." <noreply@lawnprosoftware.com>', 'To': 'virginiaross882@yahoo.com', 'Return-Path': 'E0GjyT3@47147.bongo4u.com', 'Reply-To': '"kohls.." <virginiaross7882@yahoo.com>', 'Message-ID': '<31143562.20231003180004.651c56a4879a99.64515520@mail178-175.suw51.mandrillapp.com>', 'Received-SPF': 'Fail (protection.outlook.com: domain of 47147.bongo4u.com does not designate 187.85.68.82 as permitted sender) receiver=protection.outlook.com; client-ip=187.85.68.82; helo=82-68-85-187.ppcejxunrjuuivssdbjb.nxguwuccxnqc.ldk.db;', 'Authentication-Results': 'spf=fail (sender IP is 187.85.68.82) smtp.mailfrom=47147.bongo4u.com; dkim=pass (signature was verified) header.d=lawnprosoftware.com;dmarc=pass action=none header.from=lawnprosoftware.com;compauth=pass reason=100', 'Content-Type': 'multipart/alternative; boundary="_av-m0iYsZgyNH0bBxXOhDhXoQ"', 'MIME-Version': '1.0'}
# from  noreply@lawnprosoftware.com
# return  e0gjyt3@47147.bongo4u.com
# reply  virginiaross7882@yahoo.com
# [{'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 1}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 1}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 1}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 1}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 1}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 1}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 1}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 1}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 1}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 1}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 1}, {'from_return_path_mismatch': 0, 'reply_to_from_mismatch': 1}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 1}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 0}, {'from_return_path_mismatch': 1, 'reply_to_from_mismatch': 1}]
